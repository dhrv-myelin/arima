# %%
# Out:
# Found 36 day folders under /home/dhruvkumarjiguda/code/pynb/CED
#
#   260202 (2026-02-02)  →  11,088 stroke records
#   260203 (2026-02-03)  →  11,376 stroke records
#   260204 (2026-02-04)  →  15,157 stroke records
#   260205 (2026-02-05)  →  15,589 stroke records
#   260206 (2026-02-06)  →  15,080 stroke records
#   260207 (2026-02-07)  →  14,358 stroke records
#   260208 (2026-02-08)  →      0 stroke records
#   260209 (2026-02-09)  →  13,284 stroke records
#   260210 (2026-02-10)  →  14,312 stroke records
#   260211 (2026-02-11)  →  12,360 stroke records
#   260212 (2026-02-12)  →  16,560 stroke records
#   260213 (2026-02-13)  →  16,414 stroke records
#   260214 (2026-02-14)  →  15,130 stroke records
#   260215 (2026-02-15)  →    506 stroke records
#   260216 (2026-02-16)  →  7,788 stroke records
#   260217 (2026-02-17)  →  17,619 stroke records
#   260218 (2026-02-18)  →  20,293 stroke records
#   260219 (2026-02-19)  →  18,114 stroke records
# ...
